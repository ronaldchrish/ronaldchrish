# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data =  pd.read_csv("college_1.csv")
data.head()
data.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising'],
#       dtype='object')

# %%
data2 =pd.read_csv("college_2.csv")

# %%
data2.columns
# Out:
# Index(['Name', 'python', 'python_en', 'mysql', 'computational_thinking',
#        'Previous Geekions', 'CodeKata Score', 'Department', 'Rising'],
#       dtype='object')

# %%
data = pd.concat(
    map(pd.read_csv, ['college_1.csv',"college_2.csv"]), ignore_index=True)
data
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %%
data.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising', 'python_en', 'computational_thinking'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Name                       0
# python                     0
# mysql                      0
# Previous Geekions          0
# CodeKata Score             0
# Department                 0
# Rising                     0
# python_en                 84
# computational_thinking    84
# dtype: int64

# %%
data.python_en.isnull().sum()
# Out:
# 84

# %%
data.python_en = data.python_en.fillna(0)

# %%
data.python_en.isnull().sum()
# Out:
# 0

# %%
data.computational_thinking  = data.computational_thinking .fillna(0)

# %%
data.computational_thinking.isnull().sum()
# Out:
# 0

# %%
data
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %%
data.isnull().sum()
# Out:
# Name                      0
# python                    0
# mysql                     0
# Previous Geekions         0
# CodeKata Score            0
# Department                0
# Rising                    0
# python_en                 0
# computational_thinking    0
# dtype: int64

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
exceeded = data[data['CodeKata Score']>15000]
exceeded.reset_index(drop=True)
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        0.0
# 1        Computer Science and Engineering       0        0.0
# 2        Computer Science and Engineering       0        0.0
# 3  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     0.0
# 1                     0.0
# 2                     0.0
# 3                     9.0

# %%
exceeded.to_csv("Exceeded expectations.csv",index=False)

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
reached = data[(data['CodeKata Score']>10000) & (data['CodeKata Score']<15000)]
reached.reset_index(drop=True)
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        0.0
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 0                     0.0
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
reached.to_csv("Reached_expectations.csv",index=False)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
improvement = data[(data['CodeKata Score']>7000) & (data['CodeKata Score']<10000)]
improvement.reset_index(drop=True)
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0              Sathammai.S   100.0    8.0               8980            8980
# 1             NIVEESHWAR S   100.0    0.0               8200            8200
# 2            KALAIARASAN K    85.0   47.0               7750            7880
# 3     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
improvement.to_csv("Needs_Improvement.csv",index=False)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
unsatisfied = data[data['CodeKata Score']<7000]
unsatisfied.reset_index(drop=True)
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %%
unsatisfied.to_csv("Unsatisfactory.csv",index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
data['Previous Geekions'].mean(), data['CodeKata Score'].mean()
# Out:
# (3842.3529411764707, 4051.764705882353)

# %% [markdown]
# ###### No of students participated

# %%
len(data['Name'].unique())
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
data['python'].mean()
# Out:
# 54.35294117647059

# %%
data['mysql'].mean()
# Out:
# 23.5

# %%
data['python_en'].mean()
# Out:
# 8.722689075630251

# %%
data['computational_thinking'].mean()
# Out:
# 0.6470588235294118

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
data.sort_values('CodeKata Score',ascending=False)[:3]
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
data.sort_values('Previous Geekions',ascending=False)[:3]
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt
import plotly.express as px
fig = px.pie(data,values='CodeKata Score',names='Department')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
data1 = data.sort_values('CodeKata Score',ascending=True)
fig = px.bar(data1,'Department','CodeKata Score',color='Previous Geekions',hover_name='Name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
